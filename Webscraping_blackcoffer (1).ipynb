# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup,NavigableString
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Input - Sheet1.csv')
df.head()
# Out:
#             URL_ID                                                URL
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...

# %%
df.tail()
# Out:
#              URL_ID                                                URL
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...

# %%
import os
os.makedirs('df')

# %%
#to read the title of the file from the urls
l=[]
for url in df['URL']:
    title=url.split('/')[3]
    file_name=title+'.html'
    file_path='./df/' + file_name
#to scrape the data from the url and save it to the file if the file doesnt exist in the directory
    if not os.path.exists(file_path):
        #print('file doesnt exists')
        with open(file_path,'w') as f:
            r = requests.get(url, headers={"User-Agent": "XY"})
            htmlcontent=r.content.decode()
            f.write(htmlcontent)
#to open each file and retrieve the beautifulsoup from the htmlcontent and put it in a dataframe
    with open (file_path,'r')as f:
        htmlcontent=f.read()
    soup = BeautifulSoup(htmlcontent, 'html.parser')
    title = soup.title
    article_content = soup.find('div', attrs={'class': 'td-post-content'})
    if article_content is None:
        #print('break')
        continue
    article_text=''
    for element in article_content:
        if not isinstance(element, NavigableString):
            text = element.text
            article_text+=text
    l.append(article_text)

df=pd.DataFrame(l, columns = ['Text'])
df.head()
# Out:
#                                                 Text
# 0  We have seen a huge development and dependence...
# 1  Throughout history, from the industrial revolu...
# 2  IntroductionIn the span of just a few decades,...
# 3  The way we live, work, and communicate has unq...
# 4  The year 2040 is poised to witness a continued...

# %%
import pandas as pd
outputfile=pd.read_csv('/content/drive/MyDrive/Output Data Structure.xlsx - Sheet1.csv')
outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0             NaN             NaN             NaN                 NaN
# 1             NaN             NaN             NaN                 NaN
# 2             NaN             NaN             NaN                 NaN
# 3             NaN             NaN             NaN                 NaN
# 4             NaN             NaN             NaN                 NaN
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
outputfile.tail()
# Out:
#              URL_ID                                                URL  \
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 95             NaN             NaN             NaN                 NaN
# 96             NaN             NaN             NaN                 NaN
# 97             NaN             NaN             NaN                 NaN
# 98             NaN             NaN             NaN                 NaN
# 99             NaN             NaN             NaN                 NaN
#
#     AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 95                  NaN                          NaN        NaN
# 96                  NaN                          NaN        NaN
# 97                  NaN                          NaN        NaN
# 98                  NaN                          NaN        NaN
# 99                  NaN                          NaN        NaN
#
#     AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 95                               NaN                 NaN         NaN
# 96                               NaN                 NaN         NaN
# 97                               NaN                 NaN         NaN
# 98                               NaN                 NaN         NaN
# 99                               NaN                 NaN         NaN
#
#     SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 95                NaN                NaN              NaN
# 96                NaN                NaN              NaN
# 97                NaN                NaN              NaN
# 98                NaN                NaN              NaN
# 99                NaN                NaN              NaN

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
l=[]
for i in range(98):
    new_text = df['Text'][i]

# Tokenize the new text using NLTK
    new_words = word_tokenize(new_text)
    new_filtered_words = [word for word in new_words if word.lower() not in stopwords.words('english')]
# Join the filtered words to form a clean text
    new_clean_text = ' '.join(new_filtered_words)
    l.append(new_clean_text)
df=pd.DataFrame(l,columns=['Text'])
'''print("Original Text:", new_text)
print("Text after Stopword Removal:", new_clean_text)'''
df.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 Text
# 0  seen huge development dependence people techno...
# 1  Throughout history , industrial revolution 18t...
# 2  IntroductionIn span decades , internet undergo...
# 3  way live , work , communicate unquestionably c...
# 4  year 2040 poised witness continued revolution ...
# 5  “ Entertainment giving people want . ” – Howar...
# 6  Cybercrime discussed problem twenty-first cent...
# 7  Introduction : year 2035 anticipated witness u...
# 8  Introduction : technology continues advance , ...
# 9  Understanding Cybercrime : OverviewIn year 204...

# %%
import pandas as pd
pw = pd.read_csv('/content/drive/MyDrive/Assignment /MasterDictionary/positive-words.txt')
new_row=pd.DataFrame({'a+':'a+'},index=[0])
pw=pd.concat([new_row,pw.loc[:].reset_index(drop=True)])
pw.columns=['0']
pw.reset_index(drop=True,inplace=True)
pw.head(100)
# Out:
#               0
# 0            a+
# 1        abound
# 2       abounds
# 3     abundance
# 4      abundant
# ..          ...
# 95   amiability
# 96     amiabily
# 97      amiable
# 98  amicability
# 99     amicable
#
# [100 rows x 1 columns]

# %%
# code to find and enter the the positive score of each url file in the output file

for i in range(98):
    ps=0
    #print(type(df['Text'][i]))
    for word in pw['0']:

        if word in df['Text'][i].lower():
            ps+=1
    outputfile.at[i,'POSITIVE SCORE']=ps

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0             NaN             NaN                 NaN
# 1            87.0             NaN             NaN                 NaN
# 2            54.0             NaN             NaN                 NaN
# 3            60.0             NaN             NaN                 NaN
# 4            43.0             NaN             NaN                 NaN
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#code to read and change the negative_words file data to a dataframe
import pandas as pd
with open('/content/drive/MyDrive/Assignment /MasterDictionary/negative-words.txt', 'rb') as nw:
    words = [str(w)[2:-3]for w in nw]

    nw=pd.DataFrame(words,columns=['Negative_words'])

    print(nw)
# Out:
#      Negative_words
# 0           2-faced
# 1           2-faces
# 2          abnormal
# 3           abolish
# 4        abominable
# ...             ...
# 4778           zaps
# 4779         zealot
# 4780        zealous
# 4781      zealously
# 4782         zombie
#
# [4783 rows x 1 columns]

# %%
#code to find the negative score of each url file in the output file
for i in range(98):
    ns=0
    #print(type(df['Text'][i]))
    for word in nw['Negative_words']:

        if word in df['Text'][i].lower():
            ns+=1
    outputfile.at[i,'NEGATIVE SCORE']=ns

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0             NaN                 NaN
# 1            87.0            79.0             NaN                 NaN
# 2            54.0            55.0             NaN                 NaN
# 3            60.0           125.0             NaN                 NaN
# 4            43.0            25.0             NaN                 NaN
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#polarity_score=(pos-nes)/((pos+nes)+0.000001)
for i in range(98):
    pols=0
    #print(type(df['Text'][i]))
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    pols=(pos-nes)/((pos+nes)+0.000001)


    outputfile.at[i,'POLARITY SCORE']=pols

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435                 NaN
# 1            87.0            79.0        0.048193                 NaN
# 2            54.0            55.0       -0.009174                 NaN
# 3            60.0           125.0       -0.351351                 NaN
# 4            43.0            25.0        0.264706                 NaN
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#SUBJECTIVITY SCORE=(pos+nes)/((total no.of words)+0.000001)
for i in range(98):

    #print(type(df['Text'][i]))
    text=df['Text'][i].split()
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    nofwords=len(text)
    subs=(pos+nes)/(nofwords+0.000001)


    outputfile.at[i,'SUBJECTIVITY SCORE']=subs

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                  NaN                          NaN        NaN
# 1                  NaN                          NaN        NaN
# 2                  NaN                          NaN        NaN
# 3                  NaN                          NaN        NaN
# 4                  NaN                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#avg sentence length= the number of words / the number of sentences
from nltk.tokenize import sent_tokenize,word_tokenize
for i in range(98):

    #print(type(df['Text'][i]))
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)


    outputfile.at[i,'AVG SENTENCE LENGTH']=avgsl

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                          NaN        NaN
# 1            12.939394                          NaN        NaN
# 2            14.304348                          NaN        NaN
# 3            17.078947                          NaN        NaN
# 4            14.888888                          NaN        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#POCW=nofcw/nofwords
pofcw=0
for i in range(98):
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1

    pofcw=nofcw/nofwords

    outputfile.at[i,'PERCENTAGE OF COMPLEX WORDS']=pofcw

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600        NaN
# 1            12.939394                     0.811475        NaN
# 2            14.304348                     0.854103        NaN
# 3            17.078947                     0.801233        NaN
# 4            14.888888                     0.800995        NaN
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#fogi=0.4*(avgsl+pofcw)
fogi=0
for i in range(98):
    text=df['Text'][i]

    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)

    #to find pofcw
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1
    pofcw=nofcw/nofwords

    fogi=0.4*(avgsl+pofcw)

    outputfile.at[i,'FOG INDEX']=fogi

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                               NaN                 NaN         NaN
# 1                               NaN                 NaN         NaN
# 2                               NaN                 NaN         NaN
# 3                               NaN                 NaN         NaN
# 4                               NaN                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#anofwps=nofwords/nofsents
for i in range(98):
    text=df['Text'][i]

    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    anofwps=nofwords/nofsents

    outputfile.at[i,'AVG NUMBER OF WORDS PER SENTENCE']=anofwps

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333                 NaN         NaN
# 1                         12.939394                 NaN         NaN
# 2                         14.304348                 NaN         NaN
# 3                         17.078947                 NaN         NaN
# 4                         14.888889                 NaN         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
for i in range(98):
    text=df['Text'][i]

    vowels='aeiou'
    nofcw=0

    for w in word_list:
        for v in vowels:
            if v in w:
                nofcw+=1
                break


    outputfile.at[i,'COMPLEX WORD COUNT']=nofcw

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333               764.0         NaN
# 1                         12.939394               764.0         NaN
# 2                         14.304348               764.0         NaN
# 3                         17.078947               764.0         NaN
# 4                         14.888889               764.0         NaN
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#remove the stop words
#remove the punctuations
for i in range(98):
    text=df['Text'][i]

    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    outputfile.at[i,'WORD COUNT']=nofwords
outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333               764.0       625.0
# 1                         12.939394               764.0       854.0
# 2                         14.304348               764.0       658.0
# 3                         17.078947               764.0       649.0
# 4                         14.888889               764.0       402.0
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                NaN                NaN              NaN
# 1                NaN                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN

# %%
#scpw=total no. of syllables in the text/total no of words
for i in range(98):
    text=df['Text'][i]
    vowels='aeiou'
    nofs=0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)

    nofwords=len(word_list)
    for l in text:
        if l in vowels:
            nofs+=1

    scpw=nofs/nofwords



    outputfile.at[i,'SYLLABLE PER WORD']=nofs

outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333               764.0       625.0
# 1                         12.939394               764.0       854.0
# 2                         14.304348               764.0       658.0
# 3                         17.078947               764.0       649.0
# 4                         14.888889               764.0       402.0
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0             1514.0                NaN              NaN
# 1             2410.0                NaN              NaN
# 2             2051.0                NaN              NaN
# 3             1934.0                NaN              NaN
# 4             1086.0                NaN              NaN

# %%
ppc=0
pp=['I','we','We','WE','my','My','MY','ours','OURS','Ours','us','Us']
for i in range(98):
    ppc=0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    for w in word_list:
        if w in pp:
            ppc+=1
    outputfile.at[i,'PERSONAL PRONOUNS']=ppc
outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333               764.0       625.0
# 1                         12.939394               764.0       854.0
# 2                         14.304348               764.0       658.0
# 3                         17.078947               764.0       649.0
# 4                         14.888889               764.0       402.0
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0             1514.0                0.0              NaN
# 1             2410.0                0.0              NaN
# 2             2051.0                0.0              NaN
# 3             1934.0                0.0              NaN
# 4             1086.0                0.0              NaN

# %%
#avgwl=sum of the no of chars in each word/total no ofwords
for i in range(98):
    text=df['Text'][i]
    #to find no. of words
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)

    #to find sum of chars
    nofc=0
    for w in word_list:
        cpw=len(w)
        nofc+=cpw
    avgwl=nofc/nofwords


    outputfile.at[i,'AVG WORD LENGTH']=avgwl
outputfile.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#    POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0            39.0            30.0        0.130435            0.087675
# 1            87.0            79.0        0.048193            0.154562
# 2            54.0            55.0       -0.009174            0.135741
# 3            60.0           125.0       -0.351351            0.228677
# 4            43.0            25.0        0.264706            0.143460
#
#    AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             8.333333                     0.729600   3.625173
# 1            12.939394                     0.811475   5.500348
# 2            14.304348                     0.854103   6.063380
# 3            17.078947                     0.801233   7.152072
# 4            14.888888                     0.800995   6.275953
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                          8.333333               764.0       625.0
# 1                         12.939394               764.0       854.0
# 2                         14.304348               764.0       658.0
# 3                         17.078947               764.0       649.0
# 4                         14.888889               764.0       402.0
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0             1514.0                0.0         6.380800
# 1             2410.0                0.0         7.372365
# 2             2051.0                0.0         8.227964
# 3             1934.0                0.0         8.010786
# 4             1086.0                0.0         7.445274

# %%
outputfile.to_csv('mdoutputfile.csv',index=False)
